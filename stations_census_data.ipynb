# %%
import pandas as pd

# %%
# def get_mta_data(dates):
#     file_path_string = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt'
#     dfs = []
#     for date in dates:
#         df = pd.read_csv(file_path_string.format(date))
#         dfs.append(df)
#     return pd.concat(dfs)

# %%
# df = get_mta_data(['200627', '200620'])
#Kaggle Data Sets
nyc_census_tracts = pd.read_csv('./data/nyc_census_tracts.csv')
census_block_loc = pd.read_csv('./data/census_block_loc.csv')
# Stations with Census Block ids and Census Tract ids
stations = pd.read_csv('./data/stations_with_tract_id.csv')

# %%
stations.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#                 Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria - Ditmars Blvd       Q            N W  Elevated      40.775036
# 1            Astoria Blvd       Q            N W  Elevated      40.770258
# 2                   30 Av       Q            N W  Elevated      40.766779
# 3                Broadway       Q            N W  Elevated      40.761820
# 4                   36 Av       Q            N W  Elevated      40.756804
#
#    GTFS Longitude   North Direction Label South Direction Label  \
# 0      -73.912034                     NaN             Manhattan
# ...

# %%
nyc_census_tracts['Total_Poverty'] = nyc_census_tracts['Poverty'].multiply(nyc_census_tracts['TotalPop']).multiply(1/100)
nyc_census_tracts['Total_Transit'] = nyc_census_tracts['Transit'].multiply(nyc_census_tracts['TotalPop']).multiply(1/100)

nyc_census_tracts[['Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp']]
# Out:
#       Drive  Carpool  Transit  Walk  OtherTransp
# 0       NaN      NaN      NaN   NaN          NaN
# 1      44.8     13.7     38.6   2.9          0.0
# 2      41.3     10.0     44.6   1.4          0.5
# 3      37.2      5.3     45.5   8.6          1.6
# 4      19.2      5.3     63.9   3.0          2.4
# ...     ...      ...      ...   ...          ...
# 2162   53.8      8.9     35.1   0.9          0.0
# 2163   38.7      2.4     49.4   9.5          0.0
# 2164   44.9      7.2     44.5   0.5          0.0
# 2165   53.6      8.8     32.8   4.9          0.0
# 2166    NaN      NaN      NaN   NaN          NaN
#
# [2167 rows x 5 columns]

# %%
stations_with_census = pd.merge(stations,
                                nyc_census_tracts[['CensusTract', 'Poverty', 'TotalPop', 'Total_Poverty', 'Transit', 'Total_Transit']],
                                left_on='Census Tract', 
                                right_on='CensusTract')

# %%
stations_with_census.sort_values('Total_Poverty', ascending=False).head(20)
# Out:
#      Station ID  Complex ID GTFS Stop ID Division                     Line  \
# 269         234         234          F16      IND          6th Av - Culver
# 192         156         156          A18      IND       8th Av - Fulton St
# 166         135         135          L26      BMT                 Canarsie
# 167         349         349          254      IRT              Eastern Pky
# 402         383         383          408      IRT                Jerome Av
# 165         134         134          L25      BMT                 Canarsie
# 448         441         441          227      IRT  Lenox - White Plains Rd
# 397         378         378          401      IRT                Jerome Av
# 412         393         393          622      IRT             Lexington Av
# 259         220         220          D12      IND                Concourse
# 260         221         221          B04      IND                  63rd St
# ...

# %%
stations_with_census[stations_with_census['Stop Name']=='103 St']
# Out:
#      Station ID  Complex ID GTFS Stop ID Division                Line  \
# 192         156         156          A18      IND  8th Av - Fulton St
# 345         309         309          119      IRT      Broadway - 7Av
# 414         395         395          624      IRT        Lexington Av
#
#     Stop Name Borough Daytime Routes Structure  GTFS Latitude  ...  \
# 192    103 St       M            B C    Subway      40.796092  ...
# 345    103 St       M              1    Subway      40.799446  ...
# 414    103 St       M              6    Subway      40.790600  ...
#
#      North Direction Label South Direction Label     Census Block  \
# 192     Uptown & The Bronx   Downtown & Brooklyn  360610189002000
# 345     Uptown & The Bronx              Downtown  360610191006000
# 414     Uptown & The Bronx              Downtown  360610166005001
#
#      Census Tract  CensusTract  Poverty  TotalPop  Total_Poverty  Transit  \
# ...
